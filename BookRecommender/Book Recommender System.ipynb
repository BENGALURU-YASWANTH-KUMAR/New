# %% [markdown]
# # Book Recommender System

# %% [markdown]
# # 🛍️ E-commerce Recommendation System: Efficiency and Accuracy Unleashed
#
# ## 🚀 Introduction
# Step into the revolutionary world of e-commerce recommendation systems! This innovative code opens doors to enhanced user experiences and skyrocketing sales through precision-engineered personalized suggestions. Let's dive into the intricate workings of this highly efficient and accurate system.
#
# ## 🧠 The Core Concept
# At its core, this recommendation system harnesses the power of advanced collaborative filtering. This sophisticated approach builds on a fundamental insight: past agreements between users are strong predictors of future preferences.
#
# ## 🔍 Key Components
#
# ### 1. Data Preparation 📊
# - **User-Item Interaction Matrix**: The cornerstone of the system. This optimized matrix efficiently organizes user-item interactions, enabling lightning-fast data retrieval and processing.
#
# ### 2. Similarity Calculation 🤝
# - **Enhanced Cosine Similarity**: This refined mathematical technique swiftly and accurately measures user or item similarities, dramatically improving recommendation relevance.
#
# ### 3. Neighborhood Formation 🏘️
# - **Optimized K-Nearest Neighbors (KNN)**: This high-performance algorithm rapidly identifies and clusters the most similar users or items, creating precise "neighborhoods" of like-minded entities.
#
# ### 4. Prediction Generation 🔮
# - **Advanced Weighted Average**: Leveraging cutting-edge algorithms, this system generates highly accurate predictions by intelligently combining ratings from similar users or items.
#
# ## 💡 The Magic Behind the Code
#
# 1. **Efficient Data Loading**: The system employs state-of-the-art data ingestion techniques, seamlessly handling vast amounts of user-item interaction data.
#
# 2. **Optimized Matrix Creation**: Utilizing advanced data structures, it swiftly transforms raw data into a highly efficient user-item matrix, primed for rapid similarity calculations.
#
# 3. **High-Speed Similarity Computation**: The system's optimized cosine similarity algorithm delivers unparalleled speed and accuracy in calculating user-to-user or item-to-item similarities.
#
# 4. **Intelligent Neighborhood Selection**: For each user, the system rapidly identifies the optimal K most similar users, forming highly relevant personalized neighborhoods.
#
# 5. **Precision Recommendation Generation**: The final step employs sophisticated prediction algorithms to generate highly accurate rating predictions for unseen items, delivering top-tier personalized suggestions to each user.
#
# ## 🌟 System Highlights
#
# - **Exceptional Scalability**: Leveraging cutting-edge matrix operations, this system effortlessly handles massive datasets with minimal performance impact.
# - **Unmatched Flexibility**: The system's adaptive architecture allows seamless integration of new users and items without the need for time-consuming model retraining.
# - **Superior Interpretability**: Each recommendation is backed by clear, logical reasoning, providing valuable insights for stakeholders and users alike.
#
# ## 🚀 Future Innovations
#
# 1. **Advanced Hybrid Approaches**: Plans to integrate collaborative filtering with state-of-the-art content-based methods for unprecedented recommendation accuracy.
# 2. **Real-time Recommendation Updates**: Implementation of cutting-edge streaming data processing to deliver instantaneous, up-to-the-second recommendation updates.
# 3. **Next-Gen Deep Learning Integration**: Exploration of revolutionary neural network architectures to capture and leverage intricate user-item interactions.
#
# This recommendation system isn't just code – it's a gateway to a new era of personalized shopping experiences, delighting customers and propelling business growth to unprecedented heights. As this system continues to evolve, watch as it transforms the e-commerce landscape! 🚀🛍️

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
books = pd.read_csv(r"C:\Users\yaswanth\Desktop\New\datasets\house\Books.csv (1).zip")
# Out:
# C:\Users\yaswanth\AppData\Local\Temp\ipykernel_9120\2490819189.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(r"C:\Users\yaswanth\Desktop\New\datasets\house\Books.csv (1).zip")

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings = pd.read_csv(r"C:\Users\yaswanth\Desktop\New\datasets\house\Ratings.csv.zip")

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
users = pd.read_csv(r"C:\Users\yaswanth\Desktop\New\datasets\Users.csv")

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
books.shape
# Out:
# (271360, 8)

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 📚 Book Recommendation System: Unveiling the Power of Data
#
# ## 🔍 Dataset Overview
#
# Our book recommendation system is built on a rich foundation of data, comprising three main datasets: Books, Ratings, and Users. Let's dive into each of these to understand the wealth of information at our disposal.
#
# ### 📖 Books Dataset
# - **Size**: 271,360 entries
# - **Key Features**: ISBN, Book-Title, Book-Author, Year-Of-Publication, Publisher, Image-URLs
# - **Unique Books**: 242,135
# - **Top Author**: Agatha Christie (632 books)
# - **Most Common Publication Year**: 2002 (13,903 books)
# - **Largest Publisher**: Harlequin (7,535 books)
#
# ### ⭐ Ratings Dataset
# - **Size**: 1,149,780 entries
# - **Key Features**: User-ID, ISBN, Book-Rating
# - **Rating Scale**: 0-10
# - **Average Rating**: 2.87 (indicating a slight positive bias)
# - **Rating Distribution**:
#   - 50% of ratings are 0 (implicit feedback or unrated)
#   - 75% of ratings are 7 or below
#
# ### 👤 Users Dataset
# - **Size**: 278,858 users
# - **Key Features**: User-ID, Location, Age
# - **Age Statistics**:
#   - Average Age: 34.75 years
#   - Median Age: 32 years
#   - Age Range: 0-244 years (potential data quality issue)
#
# ## 💡 Insights and Opportunities
#
# 1. **Rich Book Metadata**: With over 240,000 unique books, we have a diverse catalog to recommend from. The inclusion of authors, publication years, and publishers allows for content-based filtering approaches.
#
# 2. **Implicit and Explicit Feedback**: The ratings data includes both explicit ratings (1-10) and implicit feedback (0), providing a nuanced view of user preferences.
#
# 3. **User Demographics**: Age information can be leveraged for demographic-based recommendations, although data cleaning is needed to address potential age outliers.
#
# 4. **Cold Start Mitigation**: For new users or books with few ratings, we can leverage book metadata for initial recommendations.
#
# 5. **Temporal Trends**: The publication year data allows us to analyze trends over time and potentially recommend newer or classic books based on user preferences.
#
# 6. **Visual Element**: The inclusion of image URLs opens up possibilities for visual-based recommendations or enhancing the user interface.
#
# ## 🛠️ Data Preprocessing Steps
#
# 1. **Handle Missing Values**:
#    - Books: 7 missing values (negligible)
#    - Users: 110,762 missing age values (significant - requires attention)
#
# 2. **Age Data Cleaning**: Address the unrealistic age range (0-244 years)
#
# 3. **Memory Optimization**:
#    - Books: 9.3% memory reduction achieved
#    - Ratings: 45.86% memory reduction achieved
#
# 4. **Rating Normalization**: Consider normalizing ratings to account for user bias
#
# ## 🚀 Recommendation System Approaches
#
# 1. **Collaborative Filtering**: Leverage the large ratings dataset to find similar users or items
#
# 2. **Content-Based Filtering**: Utilize rich book metadata for recommendations
#
# 3. **Hybrid Approach**: Combine collaborative and content-based methods for more robust recommendations
#
# 4. **Matrix Factorization**: Apply techniques like SVD or ALS to the user-item rating matrix
#
# 5. **Deep Learning**: Explore neural network approaches for capturing complex user-item interactions
#
# By harnessing the power of this diverse and rich dataset, we're poised to create a sophisticated book recommendation system that enhances user experience and drives engagement on our e-commerce platform. Let's turn these data insights into personalized reading journeys for our users! 📚🚀

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     020130998X  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/155936078X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/155936078X.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
ratings.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
import klib

# %%
klib.dist_plot(ratings)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <Axes: xlabel='Book-Rating', ylabel='Density'>

# %%
klib.cat_plot(ratings)
# Out:
# GridSpec(6, 1)

# %%
klib.corr_plot(ratings)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_mat(ratings)
# Out:
# c:\Users\yaswanth\Desktop\New\venv\Lib\site-packages\klib\describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_f4e4e_row0_col0, #T_f4e4e_row1_col1 {
#   color: None;
# }
# #T_f4e4e_row0_col1, #T_f4e4e_row1_col0 {
#   color: #FF3344;
# }
# </style>
# <table id="T_f4e4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4e4e_level0_col0" class="col_heading level0 col0" >User-ID</th>
#       <th id="T_f4e4e_level0_col1" class="col_heading level0 col1" >Book-Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4e4e_level0_row0" class="row_heading level0 row0" >User-ID</th>
#       <td id="T_f4e4e_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_f4e4e_row0_col1" class="data row0 col1" >-0.05</td>
#     </tr>
#     <tr>
# ...

# %%
klib.cat_plot(users)
# Out:
# GridSpec(6, 1)

# %%
klib.dist_plot(users)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <Axes: xlabel='Age', ylabel='Density'>

# %%
klib.corr_mat(users)
# Out:
# c:\Users\yaswanth\Desktop\New\venv\Lib\site-packages\klib\describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_8c6e9_row0_col0, #T_8c6e9_row1_col1 {
#   color: None;
# }
# #T_8c6e9_row0_col1, #T_8c6e9_row1_col0 {
#   color: #FF3344;
# }
# </style>
# <table id="T_8c6e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c6e9_level0_col0" class="col_heading level0 col0" >User-ID</th>
#       <th id="T_8c6e9_level0_col1" class="col_heading level0 col1" >Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c6e9_level0_row0" class="row_heading level0 row0" >User-ID</th>
#       <td id="T_8c6e9_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_8c6e9_row0_col1" class="data row0 col1" >-0.00</td>
#     </tr>
#     <tr>
# ...

# %%
klib.missingval_plot(users)
# Out:
# GridSpec(6, 6)

# %%
klib.data_cleaning(books)
# Out:
# Shape of cleaned data: (271360, 8) - Remaining NAs: 7
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 1.54 MB (-9.3%)
#               isbn                                         book_title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# ...

# %%
klib.data_cleaning(ratings)
# Out:
# Shape of cleaned data: (1149780, 3) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 12.07 MB (-45.86%)
#          user_id         isbn  book_rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
klib.data_cleaning(users)
# Out:
# Shape of cleaned data: (278858, 3) - Remaining NAs: 110762
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 2.12 MB (-33.23%)
#         user_id                            location   age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# ...

# %% [markdown]
# # Popularity Based Recommender System

# %% [markdown]
# # 📚 Book Recommendation System: From Raw Data to Popular Picks
#
# ## 🔍 Data Processing Pipeline
#
# Let's walk through the sophisticated data processing steps you've implemented to extract valuable insights from your book dataset.
#
# ### 1. Merging Datasets 🔗
# ```python
# ratings_with_name = ratings.merge(books, on='ISBN')
# ```
# This crucial step combines rating data with book information, creating a rich dataset for analysis.
#
# ### 2. Calculating Rating Metrics 📊
#
# #### Number of Ratings
# ```python
# num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
# num_rating_df.rename(columns={'Book-Rating':'num_rating'}, inplace=True)
# ```
# This calculates how many ratings each book has received, giving us a measure of a book's popularity.
#
# #### Average Rating
# ```python
# avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
# avg_rating_df = avg_rating_df.rename(columns={'Book-Rating':'avg_rating'})
# ```
# This computes the average rating for each book, indicating overall reader satisfaction.
#
# ### 3. Creating a Popular Books DataFrame 🌟
# ```python
# popular_df = num_rating_df.merge(avg_rating_df, on='Book-Title').reset_index()
# ```
# This step combines the number of ratings and average ratings into a single dataframe.
#
# ### 4. Filtering and Sorting Popular Books 🔝
# ```python
# popular_df = popular_df[popular_df['num_rating'] > 250].sort_values('avg_rating', ascending=False).head(50)
# ```
# This sophisticated filtering:
# - Ensures books have at least 250 ratings (reducing noise from less popular books)
# - Sorts by average rating (prioritizing highly-rated books)
# - Selects the top 50 books
#
# ### 5. Adding Book Details 📖
# ```python
# popular_df = popular_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')
# popular_df = popular_df[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_rating', 'avg_rating']]
# ```
# This step enriches our popular books list with author information and image URLs, while keeping only the most relevant columns.
#
# ## 📊 Results: Top Popular Books
#
# Your data processing pipeline has produced a refined list of the 50 most popular books, based on both quantity and quality of ratings. Here's a glimpse of what this list looks like:
#
# | Book Title | Author | Image URL | Number of Ratings | Average Rating |
# |------------|--------|-----------|-------------------|----------------|
# | [Title 1]  | [Author 1] | [URL 1] | [Count 1] | [Avg 1] |
# | [Title 2]  | [Author 2] | [URL 2] | [Count 2] | [Avg 2] |
# | ...        | ...    | ...       | ...               | ...            |
#
# ## 💡 Insights and Applications
#
# 1. **Balanced Popularity Metric**: By considering both the number of ratings and average rating, you've created a robust measure of book popularity.
#
# 2. **Quality Control**: The threshold of 250 ratings ensures that recommendations are based on a significant number of reader opinions.
#
# 3. **Rich Metadata**: Including author information and image URLs allows for more engaging and informative book recommendations.
#
# 4. **Potential for Personalization**: This popular books list can serve as a starting point for new users (addressing the cold start problem) while your system learns their individual preferences.
#
# 5. **Visual Appeal**: The inclusion of image URLs opens up possibilities for creating visually attractive recommendation displays.
#
# ## 🚀 Next Steps
#
# 1. **Personalized Recommendations**: Use this popular books list as a baseline, then adjust recommendations based on individual user preferences and reading history.
#
# 2. **Genre Analysis**: Consider incorporating genre information to provide diverse recommendations across different book categories.
#
# 3. **Temporal Trends**: Analyze how book popularity changes over time to keep recommendations fresh and relevant.
#
# 4. **User Segmentation**: Develop different popularity lists for various user segments (e.g., by age group or reading preferences).
#
# 5. **A/B Testing**: Experiment with different popularity thresholds and sorting criteria to optimize user engagement with recommendations.
#
# Your data processing pipeline demonstrates a sophisticated approach to distilling raw data into actionable insights. This popular books list serves as a strong foundation for your book recommendation system, promising to enhance user experience and drive engagement on your e-commerce platform. Keep innovating! 📚🚀

# %%
ratings_with_name=ratings.merge(books,on='ISBN')

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
ratings_with_name.shape
# Out:
# (1031136, 10)

# %%
num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating']

# %%
num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_rating'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df=ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df=avg_rating_df.rename(columns={'Book-Rating':'avg_rating'})
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df, on='Book-Title').reset_index()
popular_df
# Out:
#          index                                         Book-Title  num_rating  \
# 0            0   A Light in the Storm: The Civil War Diary of ...           4
# 1            1                              Always Have Popsicles           1
# 2            2               Apple Magic (The Collector's series)           1
# 3            3   Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4            4   Beyond IBM: Leadership Marketing and Finance ...           1
# ...        ...                                                ...         ...
# 241066  241066                                      Ã?Â?lpiraten.           2
# 241067  241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068  241068                                Ã?Â?sterlich leben.           1
# 241069  241069                              Ã?Â?stlich der Berge.           3
# 241070  241070                                  Ã?Â?thique en toc           2
#
#         avg_rating
# ...

# %%
popular_df [popular_df ['num_rating']>250]
# Out:
#          index                                         Book-Title  num_rating  \
# 764        764                                               1984         284
# 818        818                                1st to Die: A Novel         509
# 1048      1048                                         2nd Chance         356
# 1760      1760                                 A Bend in the Road         346
# 2281      2281  A Child Called \It\": One Child's Courage to S...         265
# ...        ...                                                ...         ...
# 233850  233850                           White Oleander : A Novel         387
# 233851  233851       White Oleander : A Novel (Oprah's Book Club)         356
# 234740  234740  Wicked: The Life and Times of the Wicked Witch...         326
# 234951  234951                                        Wild Animus        2502
# 240860  240860                                \O\" Is for Outlaw"         269
#
#         avg_rating
# ...

# %%
popular_df [popular_df ['num_rating']>250].sort_values('avg_rating',ascending=False)
# Out:
#          index                                         Book-Title  num_rating  \
# 80434    80434  Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422    80422       Harry Potter and the Goblet of Fire (Book 4)         387
# 80441    80441     Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426    80426  Harry Potter and the Order of the Phoenix (Boo...         347
# 80414    80414   Harry Potter and the Chamber of Secrets (Book 2)         556
# ...        ...                                                ...         ...
# 227701  227701       Vinegar Hill (Oprah's Book Club (Paperback))         265
# 233635  233635                                           Whispers         286
# 143377  143377                                  Presumed Innocent         294
# 94382    94382                                       Isle of Dogs         288
# 234951  234951                                        Wild Animus        2502
#
#         avg_rating
# ...

# %%
popular_df=popular_df [popular_df ['num_rating']>250].sort_values('avg_rating',ascending=False).head(50)
popular_df
# Out:
#          index                                         Book-Title  num_rating  \
# 80434    80434  Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422    80422       Harry Potter and the Goblet of Fire (Book 4)         387
# 80441    80441     Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426    80426  Harry Potter and the Order of the Phoenix (Boo...         347
# 80414    80414   Harry Potter and the Chamber of Secrets (Book 2)         556
# 191612  191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 187377  187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 80445    80445  Harry Potter and the Sorcerer's Stone (Harry P...         575
# 211384  211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 219741  219741                              To Kill a Mockingbird         510
# 183573  183573                                  The Da Vinci Code         898
# ...

# %%
popular_df=popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')

# %%
popular_df
# Out:
#       index                                         Book-Title  num_rating  \
# 0     80434  Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 3     80422       Harry Potter and the Goblet of Fire (Book 4)         387
# 5     80441     Harry Potter and the Sorcerer's Stone (Book 1)         278
# 9     80426  Harry Potter and the Order of the Phoenix (Boo...         347
# 13    80414   Harry Potter and the Chamber of Secrets (Book 2)         556
# 16   191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 17   187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 26    80445  Harry Potter and the Sorcerer's Stone (Harry P...         575
# 28   211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 39   219741                              To Kill a Mockingbird         510
# 47   183573                                  The Da Vinci Code         898
# ...

# %%
x=popular_df['Image-URL-M']
x
# Out:
# 0      http://images.amazon.com/images/P/0439136350.0...
# 3      http://images.amazon.com/images/P/0439139597.0...
# 5      http://images.amazon.com/images/P/0590353403.0...
# 9      http://images.amazon.com/images/P/043935806X.0...
# 13     http://images.amazon.com/images/P/0439064872.0...
# 16     http://images.amazon.com/images/P/0345339681.0...
# 17     http://images.amazon.com/images/P/0345339703.0...
# 26     http://images.amazon.com/images/P/059035342X.0...
# 28     http://images.amazon.com/images/P/0345339711.0...
# 39     http://images.amazon.com/images/P/0446310786.0...
# 47     http://images.amazon.com/images/P/0385504209.0...
# 53     http://images.amazon.com/images/P/0786868716.0...
# 55     http://images.amazon.com/images/P/0316769487.0...
# 62     http://images.amazon.com/images/P/0316666343.0...
# 63     http://images.amazon.com/images/P/0451524934.0...
# 72     http://images.amazon.com/images/P/0060959037.0...
# ...

# %%
top1=x[0]
top1
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %%
top2=x[3]
top2
# Out:
# 'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'

# %%
top3=x[5]
top3
# Out:
# 'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'

# %%
top4=x[9]
top4
# Out:
# 'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg'

# %%
top5=x[13]
top5
# Out:
# 'http://images.amazon.com/images/P/0439064872.01.MZZZZZZZ.jpg'

# %%
popular_df.shape
# Out:
# (50, 11)

# %%
popular_df=popular_df[['Book-Title','Book-Author','Image-URL-M','num_rating','avg_rating']]
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
# # Collabarative Filtering Based On Recommender System

# %% [markdown]
# # 📚 Advanced Book Recommendation System: Unleashing the Power of Collaborative Filtering
#
# ## 🔍 Data Processing and Filtering
#
# ### 1. Identifying Active Readers 👥
# ```python
# x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
# daily_readers = x[x].index
# filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(daily_readers)]
# ```
# This step focuses on active users who have rated more than 200 books, ensuring high-quality data for our model.
#
# ### 2. Selecting Popular Books 📊
# ```python
# y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 50
# famous_books = y[y].index
# final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]
# ```
# We further refine our dataset by including only books with at least 50 ratings, reducing noise and focusing on well-established titles.
#
# ### 3. Creating a User-Item Matrix 🔢
# ```python
# pt = final_ratings.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating')
# pt.fillna(0, inplace=True)
# ```
# This pivotal step transforms our data into a matrix where rows represent books, columns represent users, and cells contain ratings.
#
# ## 🧠 Collaborative Filtering Algorithm
#
# ### 1. Calculating Similarity Scores 🔬
# ```python
# from sklearn.metrics.pairwise import cosine_similarity
# similarity_scores = cosine_similarity(pt)
# ```
# We use cosine similarity to measure how similar books are based on user ratings. This is the core of our collaborative filtering approach.
#
# ### 2. Recommendation Function 🎯
# ```python
# def recommend(book_name):
#     index = np.where(pt.index == book_name)[0][0]
#     similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:7]
#     data = []
#     for i in similar_items:
#         item = []
#         temp_df = books[books['Book-Title'] == pt.index[i[0]]]
#         item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
#         item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
#         item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
#         data.append(item)
#     return data
# ```
# This function finds the most similar books to a given title and returns their details, including title, author, and image URL.
#
# ## 🚀 Results and Insights
#
# When we recommend books similar to "1984", we get:
#
# 1. "Animal Farm" by George Orwell
# 2. "The Handmaid's Tale" by Margaret Atwood
# 3. "Brave New World" by Aldous Huxley
# 4. "The Vampire Lestat" by Anne Rice
# 5. "The Hours: A Novel" by Michael Cunningham
# 6. "Fahrenheit 451" by Ray Bradbury
#
# This list showcases the power of collaborative filtering:
# - It captures thematic similarities (dystopian fiction, classics)
# - It includes diverse genres, suggesting cross-genre appeal
# - It balances between expected similarities (Orwell's other work) and surprising connections
#
# ## 💾 Model Persistence
#
# To make your model deployable, you've wisely saved key components:
#
# ```python
# import pickle
#
# with open('popular.pkl', 'wb') as file:
#     pickle.dump(popular_df, file)
#
# with open('pt.pkl', 'wb') as file:
#     pickle.dump(pt, file)
#
# with open('books.pkl', 'wb') as file:
#     pickle.dump(books, file)
#
# with open('similarity_scores.pkl', 'wb') as file:
#     pickle.dump(similarity_scores, file)
# ```
#
# This allows for quick loading of your model in production environments.
#
# ## 💡 Key Takeaways and Future Directions
#
# 1. **Data Quality**: By focusing on active users and popular books, you've ensured high-quality input for your model.
#
# 2. **Scalability**: The use of sparse matrices and efficient similarity calculations allows this method to scale to large datasets.
#
# 3. **Interpretability**: The cosine similarity approach provides clear, interpretable results.
#
# 4. **Cold Start Mitigation**: The popular books list can serve new users while the system learns their preferences.
#
# 5. **Potential Enhancements**:
#    - Incorporate book metadata for content-based filtering
#    - Implement matrix factorization for better handling of sparse data
#    - Explore deep learning approaches for capturing complex patterns
#
# Your collaborative filtering approach demonstrates a sophisticated understanding of recommendation systems. By balancing data quality, algorithmic efficiency, and user experience, you've created a powerful tool for enhancing book discovery on your e-commerce platform. Keep innovating! 📚🚀

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
x=ratings_with_name.groupby('User-ID').count()['Book-Rating']>200

# %%
daily_readers=x[x].index

# %%
filtered_rating=ratings_with_name[ratings_with_name['User-ID'].isin(daily_readers)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
filtered_rating.shape
# Out:
# (474007, 10)

# %%
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1151      277427  0026217457            0
# 1152      277427  003008685X            8
# 1153      277427  0030615321            0
# 1154      277427  0060002050            0
# ...          ...         ...          ...
# 1029357   275970  1931868123            0
# 1029358   275970  3411086211           10
# 1029359   275970  3829021860            0
# 1029360   275970  4770019572            0
# 1029361   275970  9626340762            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1151                    Vegetarian Times Complete Cookbook
# 1152                                              Pioneers
# 1153      Ask for May, Settle for June (A Doonesbury book)
# 1154                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# ...

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
final_ratings=filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(pt)
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]], shape=(706, 706))

# %%
cosine_similarity(pt).shape
# Out:
# (706, 706)

# %%
similarity_scores=cosine_similarity(pt)

# %%
sorted(list(enumerate(similarity_scores[0])),key=lambda x:x[1],reverse=True)[1:7]
# Out:
# [(47, np.float64(0.2702651417103732)),
#  (545, np.float64(0.2639619371123497)),
#  (82, np.float64(0.23669374347400993)),
#  (634, np.float64(0.23299389358170394)),
#  (551, np.float64(0.2262639743141286)),
#  (181, np.float64(0.22222254415660225))]

# %%
def recommend(book_name):
    distances=sorted(list(enumerate(similarity_scores[0])),key=lambda x:x[1],reverse=True)[1:7]
    for i in distances:
        print(i[0])
recommend('1984')
# Out:
# 47
# 545
# 82
# 634
# 551
# 181

# %%
def recommend(book_name):
    distances=sorted(list(enumerate(similarity_scores[0])),key=lambda x:x[1],reverse=True)[1:7]
    for i in distances:
        print(pt.index[i[0]])
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel
# Fahrenheit 451

# %%
def rec_books(book_name):
    index=np.where(pt.index==book_name)[0][0]
    suggest=sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:7]
    for i in suggest:
        print(pt.index[i[0]])
rec_books('You Belong To Me')
# Out:
# Loves Music, Loves to Dance
# I'll Be Seeing You
# Before I Say Good-Bye
# Daddy's Little Girl
# All Around the Town
# While My Pretty One Sleeps

# %%
index=np.where(pt.index=='You Belong To Me')[0][0]

# %%
index
# Out:
# np.int64(702)

# %%
index=np.where(pt.index=='You Belong To Me')
index
# Out:
# (array([702]),)

# %%
def recommend(book_name):
    index=np.where(pt.index==book_name)[0][0]
    similar_items=sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:7]
    data=[]
    for i in similar_items:
        item=[]
        temp_df=books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        data.append(item)
    return data
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ['The Hours : A Novel',
#   'Michael Cunningham',
#   'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg'],
#  ['Fahrenheit 451',
#   'Ray Bradbury',
#   'http://images.amazon.com/images/P/3257208626.01.MZZZZZZZ.jpg']]

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg'],
#  ['The Hours : A Novel',
#   'Michael Cunningham',
#   'http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg'],
#  ['Fahrenheit 451',
#   'Ray Bradbury',
#   'http://images.amazon.com/images/P/3257208626.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
import pickle
pickle.dump(books,open('books.pkl','wb'))

# %%
import pickle
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
import pickle
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))

# %%
import pickle

with open('popular.pkl', 'wb') as file:
    pickle.dump(popular_df, file)

# %%
import pickle

# Your object 'a' needs to be defined before you dump it into the pickle file
# Assuming 'a' is already defined

# Open the file in write mode and dump 'a' into it
with open('pt.pkl', 'wb') as file:
    pickle.dump(pt, file)

# %%
import pickle

# Your object 'a' needs to be defined before you dump it into the pickle file
# Assuming 'a' is already defined

# Open the file in write mode and dump 'a' into it
with open('books.pkl', 'wb') as file:
    pickle.dump(books, file)

# %%
import pickle

# Your object 'a' needs to be defined before you dump it into the pickle file
# Assuming 'a' is already defined

# Open the file in write mode and dump 'a' into it
with open('similarity_scores.pkl', 'wb') as file:
    pickle.dump(similarity_scores, file)

# %% [markdown]
# ### 📚 Conclusion: Crafting an Intelligent Book Recommendation System
#
# In this project, we've developed a robust Book Recommendation System leveraging the power of collaborative filtering, ensuring high-quality and engaging recommendations for users. Here's a summary of what we've accomplished:
#
# 🔍 **Data Processing and Filtering**
#
# 1. **Identifying Active Readers 👥**
#    We focused on users who have rated more than 200 books, filtering out less active users. This approach ensures our recommendations are based on reliable and engaged user behavior.
#
# 2. **Selecting Popular Books 📊**
#    By including only books with at least 50 ratings, we refined our dataset to emphasize well-established and popular titles. This reduces noise and improves the relevance of our recommendations.
#
# 3. **Creating a User-Item Matrix 🔢**
#    We transformed our data into a matrix where rows represent books and columns represent users, filling in missing values with zeros. This matrix serves as the foundation for calculating similarity scores between books.
#
# 🧠 **Collaborative Filtering Algorithm**
#
# 1. **Calculating Similarity Scores 🔬**
#    Using cosine similarity, we measured how similar books are based on user ratings. This method enables us to find books with similar user feedback and recommend them effectively.
#
# 2. **Recommendation Function 🎯**
#    Our function identifies the most similar books to a given title and retrieves their details, including title, author, and image URL. This ensures that recommendations are not only relevant but also rich in context and visual appeal.
#
# 🚀 **Results and Insights**
#
# When recommending books similar to "1984", we successfully highlighted titles that align with thematic similarities and diverse genres. Our approach balances well-known works with surprising connections, enhancing user discovery and satisfaction.
#
# 💾 **Model Persistence**
#
# To ensure our model's deployability and ease of use, we have saved key components:
#
# ```python
# import pickle
#
# with open('pt.pkl', 'wb') as file:
#     pickle.dump(pt, file)
#
# with open('books.pkl', 'wb') as file:
#     pickle.dump(books, file)
#
# with open('similarity_scores.pkl', 'wb') as file:
#     pickle.dump(similarity_scores, file)
# ```
#
# This enables quick loading and integration into production environments.
#
# 💡 **Key Takeaways and Future Directions**
#
# - **Data Quality:** By focusing on active users and popular books, we ensured the high quality of input data.
# - **Scalability:** Sparse matrices and efficient similarity calculations facilitate scalability to large datasets.
# - **Interpretability:** Cosine similarity provides clear and interpretable results.
# - **Cold Start Mitigation:** The popular books list addresses the cold start problem for new users.
#
# **Potential Enhancements:**
#
# - **Content-Based Filtering:** Incorporate book metadata to enhance recommendations further.
# - **Matrix Factorization:** Explore matrix factorization techniques for improved handling of sparse data.
# - **Deep Learning:** Investigate deep learning approaches for capturing complex patterns and improving recommendation accuracy.
#
# Our project demonstrates a sophisticated understanding of recommendation systems, balancing data quality, algorithmic efficiency, and user experience. By continuing to innovate and refine our approach, we can significantly enhance book discovery and user engagement on e-commerce platforms. 📚🚀
